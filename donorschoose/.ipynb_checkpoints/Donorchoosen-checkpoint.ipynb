# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import roc_auc_score as auc
from sklearn.model_selection import StratifiedKFold
from scipy.stats import pearsonr
from nltk.stem import PorterStemmer
import re
import os
import pickle
from scipy import sparse
import pylab as pl

# %%
train=pd.read_csv('data/train.csv')
test=pd.read_csv('data/test.csv')
resources=pd.read_csv('data/resources.csv')

# %%
print(train.dtypes)
print(test.dtypes)
print(resources.dtypes)

# %%
df=pd.concat([train,test])
df.loc[df.project_essay_3.isna(),['project_essay_2','project_essay_3']]=df.loc[df.project_essay_4.isna(),['project_essay_3','project_essay_2']].values
df[['project_essay_2','project_essay_4']]=df[['project_essay_2','project_essay_4']].fillna("")
df['project_essay_1']=df.apply(lambda x:x['project_essay_1']+x['project_essay_2'],axis=1)
df['project_essay_2']=df.apply(lambda x:x['project_essay_3']+x['project_essay_4'],axis=1)
df=df.drop(['project_essay_3','project_essay_4'],axis=1)

# %%
resources['total_price']=resources['quantity'] * resources['price']

R=resources.groupby('id').agg({'description':'count','quantity':'sum','price':'sum','total_price':'sum'})\
    .rename(columns={'description':'items'})
R['avg_price']=R['total_price']/R['quantity']

for func in ['min','max','mean','std']:
    R=R.join(resources.groupby('id').agg({'quantity':func,'price':func,'total_price':func}).\
           rename(columns={'quantity':'quantity_'+func,'price':'price_'+func,'total_price':'total_price_'+func}))

R=R.join(resources.groupby('id').agg({'description':lambda x:' '.join(x.astype(str))}).rename(
    columns={'description':'resource_description'}))

df=df.join(R,on='id')

df['price_category']=pd.cut(df['total_price'], [0, 50, 100, 250, 500, 1000,np.inf])

for c in ['quantity', 'price', 'total_price']:
    df['max%s_min%s'%(c,c)] = df['%s_max'%c] - df['%s_min'%c]

# %%
le = LabelEncoder()
df['teacher_id'] = le.fit_transform(df['teacher_id'])
df['teacher_gender_unknown'] = df.teacher_prefix.apply(lambda x:int(x not in ['Ms.', 'Mrs.', 'Mr.']))

statFeatures = []
for col in ['school_state', 'teacher_id', 'teacher_prefix', 'teacher_gender_unknown', 'project_grade_category', 'project_subject_categories', 'project_subject_subcategories', 'teacher_number_of_previously_posted_projects']:
    Stat = df[['id', col]].groupby(col).agg('count').rename(columns={'id':col+'_stat'})
    Stat /= Stat.sum()
    df = df.join(Stat, on=col)

# %%
# %%time
numFeatures=[df.columns[i] for i,j in enumerate(df.dtypes) if j == 'float64' and not (df.columns[i]=='project_is_approved') ]
T2 = df[numFeatures+['project_is_approved']].copy()
Ttr = T2[-pd.isna(df.project_is_approved)]
Tar_tr = Ttr['project_is_approved'].values
n = 10
inx = [np.random.randint(0, Ttr.shape[0], int(Ttr.shape[0]/n)) for k in range(n)]
# inx is used for crossvalidation of calculating the correlation and p-value
Corr = {}
for c in numFeatures:
    # since some values might be 0s, I use x+1 to avoid missing some important relations
    C1,P1=np.nanmean([pearsonr(Tar_tr[inx[k]],   (1+Ttr[c].iloc[inx[k]])) for k in range(n)], 0)
    C2,P2=np.nanmean([pearsonr(Tar_tr[inx[k]], 1/(1+Ttr[c].iloc[inx[k]])) for k in range(n)], 0)
    if P2<P1:
        T2[c] = 1/(1+T2[c])
        Corr[c] = [C2,P2]
    else:
        T2[c] = 1+T2[c]
        Corr[c] = [C1,P1]
        
        
polyCol = []
thrP = 0.01
thrC = 0.02
print('columns \t\t\t Corr1 \t\t Corr2 \t\t Corr Combined')
for i, c1 in enumerate(numFeatures[:-1]):
    C1, P1 = Corr[c1]
    for c2 in numFeatures[i+1:]:
        C2, P2 = Corr[c2]
        V = T2[c1] * T2[c2]
        Vtr = V[-pd.isna(T2.project_is_approved)].values
        C, P = np.nanmean([pearsonr(Tar_tr[inx[k]], Vtr[inx[k]]) for k in range(n)], 0)
        if P<thrP and abs(C) - max(abs(C1),abs(C2)) > thrC:
            df[c1+'_'+c2+'_poly'] = V

# %%
dateCol = 'project_submitted_datetime'
def getTimeFeatures(T):
    df['year'] = df[dateCol].apply(lambda x: x.year)
    df['month'] = df[dateCol].apply(lambda x: x.month)
    df['day'] = df[dateCol].apply(lambda x: x.day)
    df['dow'] = df[dateCol].apply(lambda x: x.dayofweek)
    df['hour'] = df[dateCol].apply(lambda x: x.hour)
    df['days'] = (df[dateCol]-df[dateCol].min()).apply(lambda x: x.days)
    return T

df[dateCol] = pd.to_datetime(df[dateCol])
df = getTimeFeatures(df)

timeFeatures = ['year', 'month', 'day', 'dow', 'hour', 'days']
for col in timeFeatures:
    Stat = df[['id', col]].groupby(col).agg('count').rename(columns={'id':col+'_stat'})
    Stat /= Stat.sum()
    df = df.join(Stat, on=col)

# %%
def getCatFeatures(T, Col):
    vectorizer = CountVectorizer(binary=True,
                                 ngram_range=(1,1),
                                 tokenizer=lambda x:[a.strip() for a in x.split(',')])
    return vectorizer.fit_transform(T[Col].fillna(''))

X_tp = getCatFeatures(df, 'teacher_prefix')
X_ss = getCatFeatures(df, 'school_state')
X_pgc = getCatFeatures(df, 'project_grade_category')
X_psc = getCatFeatures(df, 'project_subject_categories')
X_pssc = getCatFeatures(df, 'project_subject_subcategories')

X_cat = sparse.hstack((X_tp, X_ss, X_pgc, X_psc, X_pssc))

# %%
p = PorterStemmer()
def wordPreProcess(sentence):
    return ' '.join([p.stem(x.lower()) for x in re.split('\W', sentence) if len(x) >= 1])



def getTextFeatures(T, Col, max_features=10000, ngrams=(1,2), verbose=True):
    if verbose:
        print('processing: ', Col)
    vectorizer = CountVectorizer(stop_words=None,
                                 preprocessor=wordPreProcess,
                                 max_features=max_features,
                                 binary=True,
                                 ngram_range=ngrams)
    X = vectorizer.fit_transform(T[Col])
    return X, vectorizer.get_feature_names()

n_es1, n_es2, n_prs, n_rd, n_pt = 3000, 8000, 2000, 3000, 1000
X_es1, feat_es1 = getTextFeatures(df, 'project_essay_1', max_features=n_es1)
X_es2, feat_es2 = getTextFeatures(df, 'project_essay_2', max_features=n_es2)
X_prs, feat_prs = getTextFeatures(df, 'project_resource_summary', max_features=n_prs)
X_rd, feat_rd = getTextFeatures(df, 'resource_description', max_features=n_rd, ngrams=(1,3))
X_pt, feat_pt = getTextFeatures(df, 'project_title', max_features=n_pt)

# %%
X_txt = sparse.hstack((X_es1, X_es2, X_prs, X_rd, X_pt))
del X_es1, X_es2, X_prs, X_rd, X_pt

# %%
def preprocess_str(string):
    string = re.sub(r'(\")', ' ', string)
    string = re.sub(r'(\r)', ' ', string)
    string = re.sub(r'(\n)', ' ', string)
    string = re.sub(r'(\r\n)', ' ', string)
    string = re.sub(r'(\\)', ' ', string)
    string = re.sub(r'\t', ' ', string)
    string = re.sub(r'\:', ' ', string)
    string = re.sub(r'\"\"\"\"', ' ', string)
    string = re.sub(r'_', ' ', string)
    string = re.sub(r'\+', ' ', string)
    string = re.sub(r'\=', ' ', string)

# %%
df_path='data/df.p'
if os.path.exists(df_path):
    df=pd.read_pickle('data/df.p')
else:
    df.to_pickle('data/df.p')
    
txt_path = 'data/txt.npy'
if os.path.exists(txt_path):
    X_txt = pickle.load(open(txt_path, 'rb'))
else:
    pickle.dump(X_txt, open(txt_path, 'wb'))

cat_path = 'data/cat.npy'
if os.path.exists(cat_path):
    X_cat = pickle.load(open(cat_path, 'rb'))
else:
    pickle.dump(X_cat, open(cat_path, 'wb'))

# %%
from sklearn.preprocessing import StandardScaler
numFeatures=[df.columns[i] for i,j in enumerate(df.dtypes) if j == 'float64' and not (df.columns[i]=='project_is_approved') ]
X = sparse.hstack((X_txt, X_cat, StandardScaler().fit_transform(df[numFeatures].fillna(0)))).tocsr()

Xtr = X[np.argwhere(-pd.isna(df.project_is_approved)).reshape(-1,)]
Xts = X[np.argwhere(pd.isna(df.project_is_approved)).reshape(-1,)]
Ttr_tar = df[-pd.isna(df.project_is_approved)]['project_is_approved'].values
Tts = df[-pd.isna(df.project_is_approved)][['id','project_is_approved']]

# %%
from keras.layers import Input, Dense, Flatten, concatenate, Dropout, Embedding, SpatialDropout1D
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.models import Model
from keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

n_es1, n_es2, n_prs, n_rd, n_pt = 3000, 8000, 2000, 3000, 1000
def breakInput(X1):
    X2 = []
    i = 0
    for n in [n_es1, n_es2, n_prs, n_rd, n_pt, X_cat.shape[1], len(numFeatures)]:
        X2.append(X1[:,i:i+n])
        i += n
    return X2

def getModel(HLs, Drop=0.25, OP=optimizers.Adam()):
    temp = []
    inputs_txt = []
    for n in [n_es1, n_es2, n_prs, n_rd, n_pt]:
        input_txt = Input((n, ))
        X_feat = Dropout(Drop)(input_txt)
        X_feat = Dense(int(n/100), activation="linear")(X_feat)
        X_feat = Dropout(Drop)(X_feat)
        temp.append(X_feat)
        inputs_txt.append(input_txt)

    x_1 = concatenate(temp)
#     x_1 = Dense(20, activation="relu")(x_1)
    x_1 = Dense(50, activation="relu")(x_1)
    x_1 = Dropout(Drop)(x_1)

    input_cat = Input((X_cat.shape[1], ))
    x_2 = Embedding(2, 10, input_length=X_cat.shape[1])(input_cat)
    x_2 = SpatialDropout1D(Drop)(x_2)
    x_2 = Flatten()(x_2)

    input_num = Input((len(numFeatures), ))
    x_3 = Dropout(Drop)(input_num)
    
    x = concatenate([x_1, x_2, x_3])

    for HL in HLs:
        x = Dense(HL, activation="relu")(x)
        x = Dropout(Drop)(x)

    output = Dense(1, activation="sigmoid")(x)

    model = Model(inputs=inputs_txt+[input_cat, input_num], outputs=output)
    model.compile(
            optimizer=OP,
            loss='binary_crossentropy',
            metrics=['binary_accuracy'])
    return model

def trainNN(X_train, X_val, Tar_train, Tar_val, HL=[50], Drop=0.5, OP=optimizers.Adam()):
    file_path='NN.h5'
    checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
    early = EarlyStopping(monitor="val_loss", mode="min", patience=6)
    lr_reduced = ReduceLROnPlateau(monitor='val_loss',
                                   factor=0.5,
                                   patience=2,
                                   verbose=1,
                                   epsilon=3e-4,
                                   mode='min')

    model = getModel(HL, Drop, OP)
    model.fit(breakInput(X_train), Tar_train, validation_data=(breakInput(X_val), Tar_val),
                        verbose=2, epochs=1, batch_size=1000, callbacks=[early, lr_reduced, checkpoint])
    model.load_weights(file_path)
    return model

nCV = 1 # should be ideally larger
for i in range(21, 22):
    X_train, X_val, Tar_train, Tar_val = train_test_split(Xtr, Ttr_tar, test_size=0.15, random_state=i, stratify=Ttr_tar)
    model = trainNN(X_train, X_val, Tar_train, Tar_val, HL=[50], Drop=0.5, OP=optimizers.Adam())
    Yvl3 = model.predict(breakInput(X_val)).squeeze()
    Yts3 = model.predict(breakInput(Xts)).squeeze()
# Out:
# Train on 154768 samples, validate on 27312 samples
# Epoch 1/1
#  - 105s - loss: 0.4109 - binary_accuracy: 0.8448 - val_loss: 0.3742 - val_binary_accuracy: 0.8484
#
# Epoch 00001: val_loss improved from inf to 0.37419, saving model to NN.h5

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           (None, 3000)         0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           (None, 8000)         0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, 2000)         0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           (None, 3000)         0
# __________________________________________________________________________________________________
# input_19 (InputLayer)           (None, 1000)         0
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 3000)         0           input_15[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 8000)         0           input_16[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 2000)         0           input_17[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 3000)         0           input_18[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 1000)         0           input_19[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 30)           90030       dropout_27[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 80)           640080      dropout_29[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 20)           40020       dropout_31[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 30)           90030       dropout_33[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 10)           10010       dropout_35[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 30)           0           dense_17[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 80)           0           dense_18[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 20)           0           dense_19[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 30)           0           dense_20[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 10)           0           dense_21[0][0]
# __________________________________________________________________________________________________
# input_20 (InputLayer)           (None, 100)          0
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 170)          0           dropout_28[0][0]
#                                                                  dropout_30[0][0]
#                                                                  dropout_32[0][0]
#                                                                  dropout_34[0][0]
#                                                                  dropout_36[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 100, 10)      20          input_20[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 50)           8550        concatenate_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 100, 10)      0           embedding_3[0][0]
# __________________________________________________________________________________________________
# input_21 (InputLayer)           (None, 37)           0
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 50)           0           dense_22[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1000)         0           spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 37)           0           input_21[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1087)         0           dropout_37[0][0]
#                                                                  flatten_3[0][0]
#                                                                  dropout_38[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 50)           54400       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 50)           0           dense_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1)            51          dropout_39[0][0]
# ==================================================================================================
# Total params: 933,191
# Trainable params: 933,191
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.get_config()
# Out:
# {'name': 'model_3',
#  'layers': [{'name': 'input_15',
#    'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 3000),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_15'},
#    'inbound_nodes': []},
#   {'name': 'input_16',
#    'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 8000),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_16'},
#    'inbound_nodes': []},
#   {'name': 'input_17',
#    'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 2000),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_17'},
#    'inbound_nodes': []},
#   {'name': 'input_18',
#    'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 3000),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_18'},
#    'inbound_nodes': []},
#   {'name': 'input_19',
#    'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 1000),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_19'},
#    'inbound_nodes': []},
#   {'name': 'dropout_27',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_27',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['input_15', 0, 0, {}]]]},
#   {'name': 'dropout_29',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_29',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['input_16', 0, 0, {}]]]},
#   {'name': 'dropout_31',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_31',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['input_17', 0, 0, {}]]]},
#   {'name': 'dropout_33',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_33',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['input_18', 0, 0, {}]]]},
#   {'name': 'dropout_35',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_35',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['input_19', 0, 0, {}]]]},
#   {'name': 'dense_17',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_17',
#     'trainable': True,
#     'units': 30,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['dropout_27', 0, 0, {}]]]},
#   {'name': 'dense_18',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_18',
#     'trainable': True,
#     'units': 80,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['dropout_29', 0, 0, {}]]]},
#   {'name': 'dense_19',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_19',
#     'trainable': True,
#     'units': 20,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['dropout_31', 0, 0, {}]]]},
#   {'name': 'dense_20',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_20',
#     'trainable': True,
#     'units': 30,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['dropout_33', 0, 0, {}]]]},
#   {'name': 'dense_21',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_21',
#     'trainable': True,
#     'units': 10,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['dropout_35', 0, 0, {}]]]},
#   {'name': 'dropout_28',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_28',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['dense_17', 0, 0, {}]]]},
#   {'name': 'dropout_30',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_30',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['dense_18', 0, 0, {}]]]},
#   {'name': 'dropout_32',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_32',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['dense_19', 0, 0, {}]]]},
#   {'name': 'dropout_34',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_34',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['dense_20', 0, 0, {}]]]},
#   {'name': 'dropout_36',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_36',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['dense_21', 0, 0, {}]]]},
#   {'name': 'input_20',
#    'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 100),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_20'},
#    'inbound_nodes': []},
#   {'name': 'concatenate_5',
#    'class_name': 'Concatenate',
#    'config': {'name': 'concatenate_5', 'trainable': True, 'axis': -1},
#    'inbound_nodes': [[['dropout_28', 0, 0, {}],
#      ['dropout_30', 0, 0, {}],
#      ['dropout_32', 0, 0, {}],
#      ['dropout_34', 0, 0, {}],
#      ['dropout_36', 0, 0, {}]]]},
#   {'name': 'embedding_3',
#    'class_name': 'Embedding',
#    'config': {'name': 'embedding_3',
#     'trainable': True,
#     'batch_input_shape': (None, 100),
#     'dtype': 'float32',
#     'input_dim': 2,
#     'output_dim': 10,
#     'embeddings_initializer': {'class_name': 'RandomUniform',
#      'config': {'minval': -0.05, 'maxval': 0.05, 'seed': None}},
#     'embeddings_regularizer': None,
#     'activity_regularizer': None,
#     'embeddings_constraint': None,
#     'mask_zero': False,
#     'input_length': 100},
#    'inbound_nodes': [[['input_20', 0, 0, {}]]]},
#   {'name': 'dense_22',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_22',
#     'trainable': True,
#     'units': 50,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['concatenate_5', 0, 0, {}]]]},
#   {'name': 'spatial_dropout1d_3',
#    'class_name': 'SpatialDropout1D',
#    'config': {'name': 'spatial_dropout1d_3',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['embedding_3', 0, 0, {}]]]},
#   {'name': 'input_21',
#    'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 37),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_21'},
#    'inbound_nodes': []},
#   {'name': 'dropout_37',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_37',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['dense_22', 0, 0, {}]]]},
#   {'name': 'flatten_3',
#    'class_name': 'Flatten',
#    'config': {'name': 'flatten_3', 'trainable': True},
#    'inbound_nodes': [[['spatial_dropout1d_3', 0, 0, {}]]]},
#   {'name': 'dropout_38',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_38',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['input_21', 0, 0, {}]]]},
#   {'name': 'concatenate_6',
#    'class_name': 'Concatenate',
#    'config': {'name': 'concatenate_6', 'trainable': True, 'axis': -1},
#    'inbound_nodes': [[['dropout_37', 0, 0, {}],
#      ['flatten_3', 0, 0, {}],
#      ['dropout_38', 0, 0, {}]]]},
#   {'name': 'dense_23',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_23',
#     'trainable': True,
#     'units': 50,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['concatenate_6', 0, 0, {}]]]},
#   {'name': 'dropout_39',
#    'class_name': 'Dropout',
#    'config': {'name': 'dropout_39',
#     'trainable': True,
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None},
#    'inbound_nodes': [[['dense_23', 0, 0, {}]]]},
#   {'name': 'dense_24',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_24',
#     'trainable': True,
#     'units': 1,
#     'activation': 'sigmoid',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['dropout_39', 0, 0, {}]]]}],
#  'input_layers': [['input_15', 0, 0],
#   ['input_16', 0, 0],
#   ['input_17', 0, 0],
#   ['input_18', 0, 0],
#   ['input_19', 0, 0],
#   ['input_20', 0, 0],
#   ['input_21', 0, 0]],
#  'output_layers': [['dense_24', 0, 0]]}

# %%
def nn_batch_generator(X_data, y_data, batch_size,shuffle=True):
    samples_per_epoch = X_data.shape[0]
    number_of_batches = samples_per_epoch/batch_size
    counter=0
    if shuffle:
        index = np.arange(np.shape(y_data)[0])
        np.random.shuffle(index)
        X =  X_data[index, :]
        y =  y_data[index]
    else:
        index = np.arange(np.shape(y_data)[0])
    while counter < number_of_batches:
        index_batch = index[batch_size*counter:batch_size*(counter+1)]
        X_batch = X_data[index_batch,:].todense()
        y_batch = y_data[index_batch]
        counter += 1
        yield np.array(X_batch),y_batch

# %%
import tensorflow as tf
import tensorlayer as tl
HLs=[50]
drop=0.5
learning_rate=0.001
tf.reset_default_graph()
placholder={}
input_net={}
# define placeholder
for n,label in zip([n_es1, n_es2, n_prs, n_rd, n_pt],['n_es1', 'n_es2', 'n_prs', 'n_rd', 'n_pt']):
    placholder[label] = tf.placeholder(tf.float32, shape=[None, n], name=label)
    input_net[label] = tl.layers.InputLayer(placholder[label], name=label +'_input_layer')
    input_net[label] = tl.layers.DropoutLayer(input_net[label], keep=drop, name=label+'_drop1')
    input_net[label] = tl.layers.DenseLayer(input_net[label], n_units=int(n/100), name=label+'_dense')
    input_net[label] = tl.layers.DropoutLayer(input_net[label], keep=drop, name=label+'drop2')
    
x2_placeholder= tf.placeholder(tf.int64, shape=[None, X_cat.shape[1]], name='x2')

input_num=len(numFeatures)
x3_placeholder = tf.placeholder(tf.float32, shape=[None, input_num], name='x3')

y_ = tf.placeholder(tf.float32, shape=[None, ], name='target')

x1=tl.layers.ConcatLayer([input_net[key] for key in input_net], 1, name ='input_concat_layer')
x1=tl.layers.DenseLayer(x1, n_units=50., name=label)
x1=tl.layers.DropoutLayer(x1, keep=drop, name='input_concat_layer_drop')

x2=tl.layers.EmbeddingInputlayer(inputs=x2_placeholder, vocabulary_size=2, embedding_size=10, name='x2_embed')
#x2=tl.layers.DropoutLayer(x2, keep=drop, name=label+'embed_drop')
x2 = tl.layers.FlattenLayer(x2)

x3 = tl.layers.InputLayer(x3_placeholder, name='x3_layer')
x3 = tl.layers.DropoutLayer(x3, keep=drop, name='x3_embed_drop')

x = tl.layers.ConcatLayer([x1,x2,x3])

for HL in HLs:
    x = tl.layers.DenseLayer(x, n_units=50.,act=tf.nn.relu, name='x_dense_'+str(HL))
    x = tl.layers.DropoutLayer(x, keep=drop, name='x_drop_'+str(HL))

x = tl.layers.DenseLayer(x, n_units=1,
                                act = tf.nn.sigmoid,
                                name='output_layer')

y = x.outputs
cost = tl.cost.binary_cross_entropy(y, y_,name='cross_entropy')
correct_prediction = tf.equal(tf.cast(tf.argmax(y,1),tf.float32), y_)
acc = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

train_params = x.all_params

train_op = tf.train.AdamOptimizer(learning_rate, beta1=0.9, beta2=0.999,
                            epsilon=1e-08, use_locking=False).minimize(cost, var_list = train_params)

sess = tf.InteractiveSession()
tl.layers.initialize_global_variables(sess)

n_epoch =50
batch_size = 50

X_train, X_val, Tar_train, Tar_val = train_test_split(Xtr, Ttr_tar, test_size=0.15, random_state=i, stratify=Ttr_tar)

for epoch in range(n_epoch):
    batch=nn_batch_generator(X_train, Tar_train,1000)
    for x_t,y_t in batch:
        x_t_es1, x_t_es2, x_t_prs, x_t_rd, x_t_pt,x_t_x2,x_t_x3 = breakInput(x_t)
        y_t_batch = y_t
        feed_dict={}
        
        feed_dict[placholder['n_es1']]=x_t_es1
        feed_dict[placholder['n_es2']]=x_t_es2
        feed_dict[placholder['n_prs']]=x_t_prs
        feed_dict[placholder['n_rd']]=x_t_rd
        feed_dict[placholder['n_pt']]=x_t_pt
        feed_dict[x2_placeholder]=x_t_x2
        feed_dict[x3_placeholder]=x_t_x3
        feed_dict[y_]=y_t_batch
        
        feed_dict.update(x.all_drop)  # enable noise layers
        _,c,a=sess.run([train_op,cost,acc], feed_dict=feed_dict)
        print("cost:{} accuray:{}".format(c,a))
# Out:
# [TL] InputLayer  n_es1_input_layer: (?, 3000)
# [TL] DropoutLayer n_es1_drop1: keep:0.500000 is_fix:False
# [TL] DenseLayer  n_es1_dense: 30 identity
# [TL] DropoutLayer n_es1drop2: keep:0.500000 is_fix:False
# [TL] InputLayer  n_es2_input_layer: (?, 8000)
# [TL] DropoutLayer n_es2_drop1: keep:0.500000 is_fix:False
# [TL] DenseLayer  n_es2_dense: 80 identity
# [TL] DropoutLayer n_es2drop2: keep:0.500000 is_fix:False
# [TL] InputLayer  n_prs_input_layer: (?, 2000)
# [TL] DropoutLayer n_prs_drop1: keep:0.500000 is_fix:False
# [TL] DenseLayer  n_prs_dense: 20 identity
# [TL] DropoutLayer n_prsdrop2: keep:0.500000 is_fix:False
# [TL] InputLayer  n_rd_input_layer: (?, 3000)
# [TL] DropoutLayer n_rd_drop1: keep:0.500000 is_fix:False
# [TL] DenseLayer  n_rd_dense: 30 identity
# [TL] DropoutLayer n_rddrop2: keep:0.500000 is_fix:False
# [TL] InputLayer  n_pt_input_layer: (?, 1000)
# [TL] DropoutLayer n_pt_drop1: keep:0.500000 is_fix:False
# [TL] DenseLayer  n_pt_dense: 10 identity
# [TL] DropoutLayer n_ptdrop2: keep:0.500000 is_fix:False
# [TL] ConcatLayer input_concat_layer: axis: 1
# [TL] DenseLayer  n_pt: 50 identity
# [TL] DropoutLayer input_concat_layer_drop: keep:0.500000 is_fix:False
# [TL] EmbeddingInputlayer x2_embed: (2, 10)
# [TL] FlattenLayer flatten: 1000
# [TL] InputLayer  x3_layer: (?, 37)
# [TL] DropoutLayer x3_embed_drop: keep:0.500000 is_fix:False
# [TL] ConcatLayer concat_layer: axis: -1
# [TL] DenseLayer  x_dense_50: 50 relu
# [TL] DropoutLayer x_drop_50: keep:0.500000 is_fix:False
# [TL] DenseLayer  output_layer: 1 sigmoid
# /home/ubuntu/anaconda/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py:1711: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# cost:862.283447265625 accuray:0.1469999998807907
# cost:747.1160278320312 accuray:0.16599999368190765
# cost:684.9578857421875 accuray:0.1860000044107437
# cost:600.6663818359375 accuray:0.164000004529953
# cost:558.4454956054688 accuray:0.15299999713897705
# cost:516.538330078125 accuray:0.14000000059604645
# cost:511.8632507324219 accuray:0.14900000393390656
# cost:528.6182861328125 accuray:0.16200000047683716
# cost:550.8766479492188 accuray:0.16699999570846558
# cost:507.1590270996094 accuray:0.1459999978542328
# cost:522.7245483398438 accuray:0.1550000011920929
# cost:528.783447265625 accuray:0.15700000524520874
# cost:507.9931640625 accuray:0.1509999930858612
# cost:468.7195739746094 accuray:0.13600000739097595
# cost:491.5034484863281 accuray:0.14900000393390656
# cost:473.54608154296875 accuray:0.14399999380111694
# cost:475.764892578125 accuray:0.14399999380111694
# cost:496.61798095703125 accuray:0.15800000727176666
# cost:505.36767578125 accuray:0.164000004529953
# cost:477.3748779296875 accuray:0.1459999978542328
# cost:469.9063415527344 accuray:0.1459999978542328
# cost:464.8813781738281 accuray:0.14100000262260437
# cost:475.9087219238281 accuray:0.15000000596046448
# cost:490.992431640625 accuray:0.16200000047683716
# cost:505.2853088378906 accuray:0.16699999570846558
# cost:471.86883544921875 accuray:0.15000000596046448
# cost:452.8600769042969 accuray:0.13899999856948853
# cost:486.8094482421875 accuray:0.16300000250339508
# cost:477.5438232421875 accuray:0.15700000524520874
# cost:464.78656005859375 accuray:0.15000000596046448
# cost:510.2485656738281 accuray:0.17800000309944153
# cost:444.7159729003906 accuray:0.1379999965429306
# cost:477.8789367675781 accuray:0.1589999943971634
# cost:453.9573974609375 accuray:0.1469999998807907
# cost:443.7671813964844 accuray:0.14100000262260437
# cost:502.0252990722656 accuray:0.1720000058412552
# cost:449.2215576171875 accuray:0.14399999380111694
# cost:451.8749694824219 accuray:0.14800000190734863
# cost:436.8584289550781 accuray:0.1379999965429306
# cost:491.4453125 accuray:0.16699999570846558
# cost:473.4434509277344 accuray:0.15800000727176666
# cost:470.0172424316406 accuray:0.15600000321865082
# cost:440.5670166015625 accuray:0.1420000046491623
# cost:469.34942626953125 accuray:0.15700000524520874
# cost:441.4466857910156 accuray:0.1420000046491623
# cost:500.2878112792969 accuray:0.17599999904632568
# cost:437.76806640625 accuray:0.14100000262260437
# cost:467.7852783203125 accuray:0.1589999943971634
# cost:456.305908203125 accuray:0.1509999930858612
# cost:466.2662353515625 accuray:0.15800000727176666
# cost:433.28363037109375 accuray:0.13899999856948853
# cost:455.8865051269531 accuray:0.15399999916553497
# cost:457.8566589355469 accuray:0.15399999916553497
# cost:473.0306396484375 accuray:0.16500000655651093
# cost:445.5321350097656 accuray:0.1469999998807907
# cost:421.8110656738281 accuray:0.13300000131130219
# cost:486.7498779296875 accuray:0.1720000058412552
# cost:451.52783203125 accuray:0.15199999511241913
# cost:462.5693054199219 accuray:0.15800000727176666
# cost:424.56414794921875 accuray:0.13500000536441803
# cost:454.6794738769531 accuray:0.15299999713897705
# cost:450.1460876464844 accuray:0.1509999930858612
# cost:435.07391357421875 accuray:0.14300000667572021
# cost:416.67236328125 accuray:0.13199999928474426
# cost:440.6103820800781 accuray:0.14499999582767487
# cost:487.9139404296875 accuray:0.1720000058412552
# cost:447.66265869140625 accuray:0.15000000596046448
# cost:431.19140625 accuray:0.1420000046491623
# cost:415.84088134765625 accuray:0.13300000131130219
# cost:430.66229248046875 accuray:0.14100000262260437
# cost:466.1807556152344 accuray:0.1599999964237213
# cost:467.7957458496094 accuray:0.16200000047683716
# cost:456.2331848144531 accuray:0.1550000011920929
# cost:437.22369384765625 accuray:0.14499999582767487
# cost:432.0853576660156 accuray:0.1420000046491623
# cost:459.7579650878906 accuray:0.15700000524520874
# cost:488.434814453125 accuray:0.17499999701976776
# cost:475.32861328125 accuray:0.16699999570846558
# cost:461.5907287597656 accuray:0.1599999964237213
# cost:435.74725341796875 accuray:0.14399999380111694
# cost:460.77508544921875 accuray:0.1589999943971634
# cost:446.26544189453125 accuray:0.15000000596046448
# cost:464.8289794921875 accuray:0.164000004529953
# cost:453.0072937011719 accuray:0.1550000011920929
# cost:427.25634765625 accuray:0.1379999965429306
# cost:441.8112487792969 accuray:0.1469999998807907
# cost:456.80230712890625 accuray:0.15800000727176666
# cost:458.9864196777344 accuray:0.1589999943971634
# cost:470.5745849609375 accuray:0.16599999368190765
# cost:425.3489990234375 accuray:0.13899999856948853
# cost:466.41400146484375 accuray:0.16300000250339508
# cost:429.33587646484375 accuray:0.1420000046491623
# cost:409.2167663574219 accuray:0.13099999725818634
# cost:442.8993835449219 accuray:0.15000000596046448
# cost:449.4988708496094 accuray:0.15299999713897705
# cost:418.6024475097656 accuray:0.13600000739097595
# cost:443.9224548339844 accuray:0.1509999930858612
# cost:401.6651916503906 accuray:0.12700000405311584
# cost:440.2767333984375 accuray:0.14900000393390656
# cost:459.9571228027344 accuray:0.1599999964237213
# cost:451.11041259765625 accuray:0.1550000011920929
# cost:432.4078674316406 accuray:0.14399999380111694
# cost:456.6817932128906 accuray:0.15800000727176666
# cost:490.9596862792969 accuray:0.17800000309944153
# cost:431.555419921875 accuray:0.14399999380111694
# cost:423.98199462890625 accuray:0.13899999856948853
# cost:430.86663818359375 accuray:0.14300000667572021
# cost:417.5575256347656 accuray:0.13600000739097595
# cost:436.1562194824219 accuray:0.1469999998807907
# cost:434.40875244140625 accuray:0.1459999978542328
# cost:473.6314697265625 accuray:0.16899999976158142
# cost:427.08154296875 accuray:0.1420000046491623
# cost:461.4062194824219 accuray:0.16300000250339508
# cost:455.83795166015625 accuray:0.1589999943971634
# cost:450.0226135253906 accuray:0.15600000321865082
# cost:458.05609130859375 accuray:0.1599999964237213
# cost:449.9855651855469 accuray:0.15600000321865082
# cost:438.73187255859375 accuray:0.14900000393390656
# cost:428.2281799316406 accuray:0.14399999380111694
# cost:453.3479919433594 accuray:0.15800000727176666
# cost:453.03009033203125 accuray:0.15800000727176666
# cost:433.7118225097656 accuray:0.1459999978542328
# cost:431.7987365722656 accuray:0.14499999582767487
# cost:436.1076354980469 accuray:0.1469999998807907
# cost:452.89300537109375 accuray:0.15800000727176666
# cost:474.0825500488281 accuray:0.17100000381469727
# cost:426.9774169921875 accuray:0.14300000667572021
# cost:436.6421203613281 accuray:0.14800000190734863
# cost:456.62286376953125 accuray:0.1599999964237213
# cost:425.0008850097656 accuray:0.1420000046491623
# cost:484.0810546875 accuray:0.1770000010728836
# cost:460.2066955566406 accuray:0.16300000250339508
# cost:460.642822265625 accuray:0.16300000250339508
# cost:445.4432373046875 accuray:0.15399999916553497
# cost:440.9446105957031 accuray:0.1509999930858612
# cost:439.356201171875 accuray:0.15000000596046448
# cost:447.33135986328125 accuray:0.1550000011920929
# cost:430.962646484375 accuray:0.1459999978542328
# cost:449.87481689453125 accuray:0.15700000524520874
# cost:451.27532958984375 accuray:0.15800000727176666
# cost:457.971923828125 accuray:0.16200000047683716
# cost:452.5694274902344 accuray:0.15800000727176666
# cost:438.0163269042969 accuray:0.14900000393390656
# cost:400.6552429199219 accuray:0.12800000607967377
# cost:438.9517822265625 accuray:0.1509999930858612
# cost:446.32684326171875 accuray:0.1550000011920929
# cost:445.6773986816406 accuray:0.1550000011920929
# cost:429.6375732421875 accuray:0.1459999978542328
# cost:412.89556884765625 accuray:0.13500000536441803
# cost:410.4004211425781 accuray:0.13500000536441803
# cost:427.8580627441406 accuray:0.14399999380111694
# cost:443.0172119140625 accuray:0.15299999713897705
# cost:463.8290710449219 accuray:0.16500000655651093
# cost:453.4098815917969 accuray:0.1589999943971634
# cost:352.4693603515625 accuray:0.1627604216337204
# cost:430.2279968261719 accuray:0.1459999978542328
# cost:469.0174865722656 accuray:0.16899999976158142
# cost:438.9743957519531 accuray:0.1509999930858612
# cost:432.9003601074219 accuray:0.1469999998807907
# cost:427.65582275390625 accuray:0.14399999380111694
# cost:444.0166931152344 accuray:0.15399999916553497
# cost:433.804931640625 accuray:0.14800000190734863
# cost:448.0291748046875 accuray:0.15700000524520874
# cost:481.01556396484375 accuray:0.17599999904632568
# cost:463.137451171875 accuray:0.16599999368190765
# cost:440.6553649902344 accuray:0.15199999511241913
# cost:451.2205505371094 accuray:0.1589999943971634
# cost:433.93255615234375 accuray:0.14800000190734863
# cost:438.5600891113281 accuray:0.1509999930858612
# cost:436.9085998535156 accuray:0.15000000596046448
# cost:445.0085754394531 accuray:0.15600000321865082
# cost:447.53704833984375 accuray:0.15700000524520874
# cost:474.3373718261719 accuray:0.1720000058412552
# cost:451.73028564453125 accuray:0.1599999964237213
# cost:459.85662841796875 accuray:0.16500000655651093
# cost:437.9585266113281 accuray:0.1509999930858612
# cost:453.1858215332031 accuray:0.16099999845027924
# cost:434.9096374511719 accuray:0.14800000190734863
# cost:456.8186950683594 accuray:0.16300000250339508
# cost:449.1404113769531 accuray:0.15800000727176666
# cost:438.0331726074219 accuray:0.1509999930858612
# cost:419.2335205078125 accuray:0.14000000059604645
# cost:421.989990234375 accuray:0.1420000046491623
# cost:448.9007873535156 accuray:0.15800000727176666
# cost:452.49786376953125 accuray:0.1599999964237213
# cost:469.54443359375 accuray:0.17000000178813934
# cost:427.1608581542969 accuray:0.14499999582767487
# cost:417.8089599609375 accuray:0.14000000059604645
# cost:481.5823059082031 accuray:0.17599999904632568
# cost:413.8580017089844 accuray:0.1379999965429306
# cost:463.20867919921875 accuray:0.16599999368190765
# cost:411.8278503417969 accuray:0.13699999451637268
# cost:450.14385986328125 accuray:0.1589999943971634
# cost:441.63604736328125 accuray:0.15399999916553497
# cost:440.06829833984375 accuray:0.15299999713897705
# cost:447.3070373535156 accuray:0.15700000524520874
# cost:423.0708312988281 accuray:0.14300000667572021
# cost:426.6627197265625 accuray:0.14499999582767487
# cost:453.0736389160156 accuray:0.16099999845027924
# cost:431.23907470703125 accuray:0.14800000190734863
# cost:445.7336120605469 accuray:0.15700000524520874
# cost:428.6394348144531 accuray:0.1459999978542328
# cost:428.66192626953125 accuray:0.1469999998807907
# cost:419.886962890625 accuray:0.1420000046491623
# cost:403.361572265625 accuray:0.13300000131130219
# cost:455.95660400390625 accuray:0.16200000047683716
# cost:426.0562438964844 accuray:0.14499999582767487
# cost:416.95880126953125 accuray:0.14000000059604645
# cost:452.7532958984375 accuray:0.1599999964237213
# cost:423.3592529296875 accuray:0.14399999380111694
# cost:417.50225830078125 accuray:0.14000000059604645
# cost:421.8314208984375 accuray:0.14300000667572021
# cost:449.27593994140625 accuray:0.1589999943971634
# cost:447.6506652832031 accuray:0.15800000727176666
# cost:464.6980285644531 accuray:0.1679999977350235
# cost:423.98681640625 accuray:0.14399999380111694
# cost:441.6156311035156 accuray:0.15399999916553497
# cost:473.0472412109375 accuray:0.17399999499320984
# cost:418.1173400878906 accuray:0.14000000059604645
# cost:413.1065368652344 accuray:0.13600000739097595
# cost:414.4671325683594 accuray:0.1379999965429306
# cost:402.5383605957031 accuray:0.13099999725818634
# cost:452.0918273925781 accuray:0.16099999845027924
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-75d1590caf06> in <module>()
#      78
#      79         feed_dict.update(x.all_drop)  # enable noise layers
# ---> 80         _,c,a=sess.run([train_op,cost,acc], feed_dict=feed_dict)
#      81         print("cost:{} accuray:{}".format(c,a))
#
# ~/anaconda/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/anaconda/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/anaconda/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
# Out:
# <tf.Tensor 'output_layer/Sigmoid:0' shape=(?, 1) dtype=float32>
